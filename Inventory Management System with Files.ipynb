# %%
#In Inventory, format is: Product_ID,Product_Name,price,qty
import time

# Reading the Inventory
fd = open('Inventory.txt','r')  
products = fd.read().split('\n')
fd.close()

# Taking User Input
ui_username = input("Enter your Name: ")
ui_phone    = input("Enter your Phone No: ")
ui_prod_id  = input("Enter product ID: ")
ui_prod_qn  = input("Enter product Quantity: ")

updated_product_lst = []

# Going through each product detail
for product in products:
    prod_details = product.split(',')
    if(prod_details[0] == ui_prod_id):
    # Checking if product exists or not

        if (int(ui_prod_qn) <= int(prod_details[3])):
        
            print("-----------------------------")
            print("Product Name     : ", prod_details[1])
            print("Price            : ", prod_details[2]) 
            print("Quantity         : ", ui_prod_qn) 
            print("-----------------------------")
            print("Billing Amount   : ", int(ui_prod_qn) * int(prod_details[2]))
            print("-----------------------------")

            # Updating Inventory list
            prod_details[3] = str(int(prod_details[3]) - int(ui_prod_qn))
            
            # Generating Sales in Sales.txt
            fd = open("Sales.txt",'a')
            sales_detail = f"{ui_username},{ui_phone} bought {prod_details[1]} with quantity= {ui_prod_qn} at {time.ctime()}. The billing amount is: {int(ui_prod_qn) * int(prod_details[2])}\n"
            fd.write(sales_detail)
            fd.close()
            
        else:
            print("Sorry, We're not having enough quantity.")
            print("We're having only",prod_details[3],'quantity.')
            print("Would you like to purchase the remaining quantities only?")
            
            ch = input("Press Y/N: ")
            
            if (ch == 'Y' or ch == 'y'):
            
                print("-----------------------------")
                print("Product Name     : ", prod_details[1])
                print("Price            : ", prod_details[2]) 
                print("Quantity         : ", prod_details[3]) 
                print("-----------------------------")
                print("Billing Amount   : ", int(prod_details[3]) * int(prod_details[2]))
                print("-----------------------------")
                
                # Generating Sales in Sales.txt
                fd = open("Sales.txt",'a')
                sales_detail = f"{ui_username},{ui_phone} bought {prod_details[1]} with quantity= {ui_prod_qn} at {time.ctime()}. The billing amount is: {int(ui_prod_qn) * int(prod_details[2])}\n"
                fd.write(sales_detail)
                fd.close()
                
                
                prod_details[3] = '0'

            else:
                print("Thanks")
            
    # Updating my Inventory List
    updated_product_lst.append(prod_details)
    

    
lst = []

# Updating my Inventory String
for i in updated_product_lst:
    prod = i[0] +","+  i[1] +","+ i[2] +","+ i[3] + '\n'
    lst.append(prod)

# Removing Last \n from the list
lst[-1] = lst[-1][:-1]
    

# Updating Inventory File
fd = open('Inventory.txt','w')

for i in lst:
    fd.write(i)
fd.close()

print("Inventory Updated")
# Out:
# Enter your Name:  Sunny
# Enter your Phone No:  9304478966
# Enter product ID:  4
# Enter product Quantity:  10
# -----------------------------
# Product Name     :  Oreo
# Price            :  25
# Quantity         :  10
# -----------------------------
# Billing Amount   :  250
# -----------------------------
# Inventory Updated
